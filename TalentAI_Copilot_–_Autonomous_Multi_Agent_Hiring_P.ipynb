# %% [markdown]
# <a href="https://colab.research.google.com/github/prasa397/Analyst-/blob/main/TalentAI_Copilot_%E2%80%93_Autonomous_Multi_Agent_Hiring_P.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import os

# Paths
workspace_dir = "/content"
app_py_path = os.path.join(workspace_dir, "app.py")
notebook_path = os.path.join(workspace_dir, "talentai_copilot_kaggle.ipynb")

if not os.path.exists(app_py_path):
    raise FileNotFoundError(f"Source file app.py not found at {app_py_path}")

# Read app.py content
with open(app_py_path, 'r', encoding='utf-8') as f:
    app_code_lines = f.readlines()

# Prepare cell sources (must be list of strings ending with newlines)
app_writefile_source = ["%%writefile app.py\n"] + app_code_lines

# Define notebook structure
notebook_data = {
    "cells": [
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "# 🤖 TalentAI Copilot: Autonomous Multi-Agent Hiring Platform\n",
                "\n",
                "TalentAI Copilot is an enterprise-grade Autonomous Multi-Agent Hiring Platform designed to transform the recruitment lifecycle using Google's Agentic AI ecosystem.\n",
                "\n",
                "This notebook bundles the **Streamlit Recruiter Portal** and launches a public tunnel so you can test it directly from the Kaggle environment!\n",
                "\n",
                "### ☁ Google Technologies Demoed:\n",
                "- **Gemini 2.5 Pro** (LLM Reasoning)\n",
                "- **Vertex AI Embeddings** (Semantic Search & Matching)\n",
                "- **Agent Development Kit (ADK)** (Multi-Agent Orchestrator)\n",
                "- **BigQuery & Firestore** (Telemetry & Analytics)"
            ]
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "### 1. Write the Streamlit Code to Disk"
            ]
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": app_writefile_source
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "### 2. Install Platform Dependencies"
            ]
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "# Install Streamlit and Matplotlib\n",
                "!pip install -q streamlit matplotlib pandas numpy"
            ]
        },
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "### 3. Launch Streamlit Server & Expose via Public Tunnel\n",
                "\n",
                "We use `localhost.run` (a free SSH tunneling service) to tunnel our local Streamlit port (8501) to a public address. \n",
                "\n",
                "**Instructions:**\n",
                "1. Run the cell below.\n",
                "2. Click the public `https://...` link printed in the output logs to open the interactive app."
            ]
        },
        {
            "cell_type": "code",
            "execution_count": None,
            "metadata": {},
            "outputs": [],
            "source": [
                "# Run Streamlit in background and tunnel port 8501\n",
                "import subprocess\n",
                "import os\n",
                "\n",
                "print(\"Starting Streamlit and Tunnel... Please click the generated secure link below when it appears.\")\n",
                "cmd = \"streamlit run app.py --server.port 8501 & ssh -o StrictHostKeyChecking=no -R 80:localhost:8501 nosecurity@localhost.run\"\n",
                "os.system(cmd)"
            ]
        }
    ],
    "metadata": {
        "kernelspec": {
            "display_name": "Python 3",
            "language": "python",
            "name": "python3"
        },
        "language_info": {
            "name": "python"
        }
    },
    "nbformat": 4,
    "nbformat_minor": 2
}

# Write notebook to file
with open(notebook_path, 'w', encoding='utf-8') as f:
    json.dump(notebook_data, f, indent=2)

print(f"Successfully generated Jupyter Notebook at: {notebook_path}")
# Out:
# Successfully generated Jupyter Notebook at: /content/talentai_copilot_kaggle.ipynb

# %%
# Install Streamlit and Matplotlib
# !pip install -q streamlit matplotlib pandas numpy
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 53.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 97.9 MB/s eta 0:00:00

# %%
pip install -q pyngrok

# %% [markdown]
# ### 4. Setup ngrok Tunnel
#
# To use ngrok, you need an authtoken. If you don't have one, you can get it from [ngrok dashboard](https://dashboard.ngrok.com/get-started/your-authtoken). Once you have it, add it to Colab secrets as `NGROK_AUTH_TOKEN`.

# %%
from pyngrok import ngrok
from google.colab import userdata

# Terminate any existing ngrok tunnels
ngrok.kill()

# Get ngrok authtoken from Colab secrets
NGROK_AUTH_TOKEN = userdata.get('NGROK_AUTH_TOKEN')

if not NGROK_AUTH_TOKEN:
    raise ValueError("NGROK_AUTH_TOKEN not found in Colab secrets. Please add it.")

# Authenticate ngrok
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# Open a tunnel to port 8501 (Streamlit's default port)
public_url = ngrok.connect(8501)
print(f"Streamlit App Public URL: {public_url}")
# Out:
# Streamlit App Public URL: NgrokTunnel: "https://cf72-35-196-252-103.ngrok-free.app" -> "http://localhost:8501"

# %%
from google.colab import userdata

try:
    token = userdata.get('NGROK_AUTH_TOKEN')
    if token:
        print("NGROK_AUTH_TOKEN is set and accessible.")
    else:
        print("NGROK_AUTH_TOKEN is set, but its value might be empty or invalid.")
except Exception as e:
    print(f"NGROK_AUTH_TOKEN is NOT set or accessible. Error: {e}")
# Out:
# NGROK_AUTH_TOKEN is set and accessible.

# %%
from google.colab import userdata

try:
    token = userdata.get('NGROK_AUTH_TOKEN')
    if token:
        print("NGROK_AUTH_TOKEN is set and accessible.")
    else:
        print("NGROK_AUTH_TOKEN is set, but its value might be empty or invalid.")
except Exception as e:
    print(f"NGROK_AUTH_TOKEN is NOT set or accessible. Error: {e}")
# Out:
# NGROK_AUTH_TOKEN is set and accessible.

# %%
# Run Streamlit in background
import subprocess

print("Starting Streamlit app...")
subprocess.Popen(["streamlit", "run", "app.py", "--server.port", "8501", "--server.enableCORS", "False", "--server.enableXsrfProtection", "False"])
# Out:
# Starting Streamlit app...
# <Popen: returncode: None args: ['streamlit', 'run', 'app.py', '--server.port...>

# %%
# The Streamlit app is already running from cell ef6027ff,
# and the ngrok tunnel is established in cell 748807bb.
# This cell's command was causing conflicts by attempting a second Streamlit instance and a localhost.run tunnel.
# Therefore, its content has been commented out to ensure smooth operation.

# import subprocess
# import os

# print("Starting Streamlit and Tunnel... Please click the generated secure link below when it appears.")
# cmd = "streamlit run app.py --server.port 8501 & ssh -o StrictHostKeyChecking=no -R 80:localhost:8501 nosecurity@localhost.run"
# os.system(cmd)
